# %% [markdown]
# Objective of the Research:
#
# The objective of my research is to uncover insights about the evolution of the business aspect of the movie industry. Understanding audience preferences, and helping writers and directors with the best possible portrayal of their story and imagination on the screen is a vital focus of any company and producer. Being able to make data-driven decisions and picking up market trends can make significant changes in the revenue stream and profit.
#
# The key focuses of my analysis are the following:
#
# Genre
#
# Writer
#
# Director
#
# Budget
#
# Profit

# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pd.options.mode.chained_assignment = None




# Now we need to read in the data
# Now we need to read in the data
data = pd.read_csv('/content/movies.csv')

# %% [markdown]
# i. Glimpse of the Data

# %%
data.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %% [markdown]
# ii. Knowing of the Data:

# %%
data.shape
# Out:
# (7668, 15)

# %% [markdown]
# Obeservation: The dataset comprises 7668 rows and 15 columns. The rows are information about different movies that were released from 1980 to 2020. The columns provide valuable information about each of the movies.

# %%
# Columns of the data
data.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %% [markdown]
# Obeservation: The dataset comprises 7668 rows and 15 columns. The rows are information about different movies that were released from 1980 to 2020. The columns provide valuable information about each of the movies.
#
# Obeservation: The columns of the dataset provide valuable information about each movie.
#
# name: Name of the Movie
#
# rating: Rating of the movie (R, PG, etc.)
#
# genre: Main Genre of the movie
#
# year: Year of Release
#
# released: Release Date(YYYY-MM-DD)(location)
#
# score: IMDb user rating
#
# votes: Number of user votes
#
# director: Name of the Director
#
# writer: Name of the Writer
#
# star: Main Actor/Actress
#
# country: Country of Origin
#
# budget: Budget of the movie
#
# gross: Revenue of the movie
#
# company: The Production Company
#
# runtime: Duration of the movie in minutes

# %%
data["genre"].unique()
# Out:
# array(['Drama', 'Adventure', 'Action', 'Comedy', 'Horror', 'Biography',
#        'Crime', 'Fantasy', 'Family', 'Sci-Fi', 'Animation', 'Romance',
#        'Music', 'Western', 'Thriller', 'History', 'Mystery', 'Sport',
#        'Musical'], dtype=object)

# %% [markdown]
# Obeservation: There are 19 unique genres of movies in the dataset.

# %% [markdown]
# Obeservation: Most of the missing values in the dataset are observed in the budget column, followed by gross and some values from other columns.
#
# Decision: For the sake of our analysis, we shall remove all the missing values.

# %% [markdown]
# Now, Let's Get a Quick Overview

# %%
print(f"Records: {data.shape[0]}")
print(f"Features: {data.shape[1]}")
# Out:
# Records: 7668
# Features: 15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# Calculating the missing values in different columns
data.isnull().sum().sort_values(ascending=False)
# Out:
# budget      2171
# gross        189
# rating        77
# company       17
# runtime        4
# score          3
# votes          3
# writer         3
# country        3
# released       2
# star           1
# name           0
# genre          0
# year           0
# director       0
# dtype: int64

# %% [markdown]
# Obeservation: Most of the missing values in the dataset are observed in the budget column, followed by gross and some values from other columns.
#
# Decision: For the sake of our analysis, we shall remove all the missing values.

# %%
# Removing Missing Values

dataFrame.isnull().sum().sort_values(ascending = False)
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
dataFrame.shape
# Out:
# (5421, 15)

# %% [markdown]
# Obeservation: After removing the missing values, we are left with information about 5421 movies.

# %% [markdown]
# iii. Introducing New Features

# %%
dataFrame["profit"] = dataFrame["gross"] - dataFrame["budget"]
dataFrame['result'] = dataFrame['profit'].apply(lambda x: 'hit' if x > 0 else 'flop')
dataFrame.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %% [markdown]
# Obeservation: Since we are focused on the business side of things, we calculated profit from the gross revenue and budget and also classified films as hit/flop based on the profit

# %% [markdown]
# Analyzing on Various Factors of the Data:

# %% [markdown]
# i. Based on Score:

# %%
#by score
highest_rated_movies = dataFrame.groupby('year').apply(lambda x: x.loc[x['score'].idxmax()])
highest_rated_movies.head(10)
# Out:
#                                                 name rating      genre  year  \
# year
# 1980  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 1981   Indiana Jones and the Raiders of the Lost Ark     PG     Action  1981
# 1982                                    Blade Runner      R     Action  1982
# 1983                                        Scarface      R      Crime  1983
# 1984                     Once Upon a Time in America      R      Crime  1984
# 1985                              Back to the Future     PG  Adventure  1985
# 1986                                          Aliens      R     Action  1986
# 1987                               Full Metal Jacket      R      Drama  1987
# 1988                                 Cinema Paradiso     PG      Drama  1988
# 1989              Indiana Jones and the Last Crusade  PG-13     Action  1989
#
#                                released  score      votes            director  \
# year
# ...

# %%
hit_count = len(highest_rated_movies[highest_rated_movies['result']=="hit"])
flop_count = len(highest_rated_movies[highest_rated_movies['result'] == "flop"])


print(f"Number of Hit Films: {hit_count}")
print(f"Number of Flop Films: {flop_count}")
# Out:
# Number of Hit Films: 40
# Number of Flop Films: 1

# %% [markdown]
# Obeservation: This subset has the highest rated movies over the years. We can also observe although one of the movies was highest rated of a particular year, it still was flop based on the revenue generation.

# %% [markdown]
# ii. Based on Budget:

# %%
# by budget
movies_with_highest_budget = dataFrame.groupby('year').apply(lambda x: x.loc[x['budget'].idxmax()])
movies_with_highest_budget.head(10)
# Out:
#                          name rating      genre  year  \
# year
# 1980              Superman II     PG     Action  1980
# 1981                   Inchon     PG      Drama  1981
# 1982                    Annie     PG     Comedy  1982
# 1983                    Krull     PG     Action  1983
# 1984          The Cotton Club      R      Crime  1984
# 1985   Santa Claus: The Movie     PG  Adventure  1985
# 1986                  Pirates  PG-13     Action  1986
# 1987                   Ishtar  PG-13     Action  1987
# 1988  Who Framed Roger Rabbit     PG  Animation  1988
# 1989                The Abyss  PG-13  Adventure  1989
#
#                                 released  score     votes  \
# year
# 1980       June 19, 1981 (United States)    6.8  101000.0
# 1981  September 17, 1982 (United States)    2.7     659.0
# 1982       June 18, 1982 (United States)    6.6   41000.0
# 1983       July 29, 1983 (United States)    6.1   31000.0
# 1984   December 14, 1984 (United States)    6.5   17000.0
# ...

# %%
hit_count = len(movies_with_highest_budget[movies_with_highest_budget['result']=="hit"])
flop_count = len(movies_with_highest_budget[movies_with_highest_budget['result'] == "flop"])


print(f"Number of Hit Films: {hit_count}")
print(f"Number of Flop Films: {flop_count}")
# Out:
# Number of Hit Films: 35
# Number of Flop Films: 6

# %% [markdown]
# Obeservation: This subset has the movies with the highest budget over the years. We can also observe that 6 of the 35 films, turned out to be flop although they had a massive budget compared to the other films that came out on that particular year.

# %% [markdown]
# iii. Based on Votes:

# %%
# by votes
movies_with_highest_votes = dataFrame.groupby('year').apply(lambda x: x.loc[x['votes'].idxmax()])
movies_with_highest_votes.head(10)
# Out:
#                                                 name rating      genre  year  \
# year
# 1980  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 1981   Indiana Jones and the Raiders of the Lost Ark     PG     Action  1981
# 1982                                    Blade Runner      R     Action  1982
# 1983      Star Wars: Episode VI - Return of the Jedi     PG     Action  1983
# 1984                                  The Terminator      R     Action  1984
# 1985                              Back to the Future     PG  Adventure  1985
# 1986                                          Aliens      R     Action  1986
# 1987                               Full Metal Jacket      R      Drama  1987
# 1988                                        Die Hard      R     Action  1988
# 1989              Indiana Jones and the Last Crusade  PG-13     Action  1989
#
#                               released  score      votes          director  \
# year
# ...

# %%
hit_count = len(movies_with_highest_votes[movies_with_highest_votes['result']=="hit"])
flop_count = len(movies_with_highest_votes[movies_with_highest_votes['result'] == "flop"])


print(f"Number of Hit Films: {hit_count}")
print(f"Number of Flop Films: {flop_count}")
# Out:
# Number of Hit Films: 41
# Number of Flop Films: 0

# %% [markdown]
# Obeservation: These movies can be considered as the highest watched movies over the years. We observe that all of them successful on the terms of profit generation.

# %% [markdown]
# iv. Based on Gross Revenue:

# %%
# by gross revenue
movies_with_highest_gross_revenue = dataFrame.groupby('year').apply(lambda x: x.loc[x['gross'].idxmax()])
movies_with_highest_gross_revenue.head(10)
# Out:
#                                                 name rating      genre  year  \
# year
# 1980  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 1981   Indiana Jones and the Raiders of the Lost Ark     PG     Action  1981
# 1982                      E.T. the Extra-Terrestrial     PG     Family  1982
# 1983      Star Wars: Episode VI - Return of the Jedi     PG     Action  1983
# 1984            Indiana Jones and the Temple of Doom     PG     Action  1984
# 1985                              Back to the Future     PG  Adventure  1985
# 1986                                         Top Gun     PG     Action  1986
# 1987                                Fatal Attraction      R      Drama  1987
# 1988                                        Rain Man      R      Drama  1988
# 1989              Indiana Jones and the Last Crusade  PG-13     Action  1989
#
#                                 released  score      votes          director  \
# year
# ...

# %%
hit_count = len(movies_with_highest_gross_revenue[movies_with_highest_gross_revenue['result']=="hit"])
flop_count = len(movies_with_highest_gross_revenue[movies_with_highest_gross_revenue['result'] == "flop"])


print(f"Number of Hit Films: {hit_count}")
print(f"Number of Flop Films: {flop_count}")
# Out:
# Number of Hit Films: 41
# Number of Flop Films: 0

# %% [markdown]
# Obeservation: This subset has contains movies with the highest gross revenue over the years. All of them were economically successful as it was expected

# %% [markdown]
# v. Based on Profit:

# %%
# by profit
highest_profit_generating_movies = dataFrame.groupby('year').apply(lambda x: x.loc[x['profit'].idxmax()])
highest_profit_generating_movies.head(10)
# Out:
#                                                 name rating      genre  year  \
# year
# 1980  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 1981   Indiana Jones and the Raiders of the Lost Ark     PG     Action  1981
# 1982                      E.T. the Extra-Terrestrial     PG     Family  1982
# 1983      Star Wars: Episode VI - Return of the Jedi     PG     Action  1983
# 1984            Indiana Jones and the Temple of Doom     PG     Action  1984
# 1985                              Back to the Future     PG  Adventure  1985
# 1986                                         Top Gun     PG     Action  1986
# 1987                                Fatal Attraction      R      Drama  1987
# 1988                                        Rain Man      R      Drama  1988
# 1989              Indiana Jones and the Last Crusade  PG-13     Action  1989
#
#                                 released  score      votes          director  \
# year
# ...

# %% [markdown]
# Obeservation: This subset contains movies with the highest profit over the years.

# %% [markdown]
# Visualizing different Aspects and Trends:

# %% [markdown]
# i. Genre Distribution:

# %%
def create_pie_chart_data(subset, title):
    genre_counts = subset['genre'].value_counts()
    fig = go.Figure(data=[go.Pie(labels=genre_counts.index, values=genre_counts.values, textinfo='percent+label')])
    fig.update_layout(title_text=title)
    return fig



fig1 = create_pie_chart_data(highest_rated_movies, "Genre Distribution of Highest Score")
fig2 = create_pie_chart_data(movies_with_highest_budget, "Genre Distribution of Highest Budget")
fig3 = create_pie_chart_data(movies_with_highest_votes, "Genre Distribution of Highest Vote ")
fig4 = create_pie_chart_data(highest_profit_generating_movies, "Genre Distribution of Highest Profit ")


fig = make_subplots(rows=2, cols=2, subplot_titles=["Highest Score", "Highest Budget", "Highest Vote", "Highest Profit"],specs=[[{"type": "pie"}, {"type": "pie"}],
           [{"type": "pie"}, {"type": "pie"}]],
)
fig.add_trace(fig1.data[0], row=1, col=1)
fig.add_trace(fig2.data[0], row=1, col=2)
fig.add_trace(fig3.data[0], row=2, col=1)
fig.add_trace(fig4.data[0], row=2, col=2)

fig.update_layout(width=1000, height=800,title="Genre Distribution", showlegend=False)
fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="LightSteelBlue")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Obeservation:The pie chart helps us to understand industry preferences and audience preferences for different genres of movies.
#
# 73.2% of the movies with the most budget are Action movies, followed by Adventure with 9.76% and Animation with 7.32%.
#
# Action movies are also the ones with the most numbers of economically successful films(63.4%). Animation(14.6%) comes in second followed by Drama(9.76%).
#
#
# A similar gap in numbers is not observed in the case of Scoring. Action and Drama come really close with 36.6% and 22% followed by Crime at 17.1%, Biography at 9.76%, and Adventure at 7.32%.
#
# But the presence of Action in Voting is again noteworthy.51.2% followed by Crime, Drama, Adventure, and Biography at 17.1%, 14.6%, 9.76%, and 7.32% respectively.

# %% [markdown]
# ii. Top Directors Over the Years:

# %%
def create_bar_plot_data(subset, column_name):
    top_counts = subset[column_name].value_counts().nlargest(10)
    colors = px.colors.qualitative.Set3
    color_mapping = dict(zip(top_counts.index, colors))
    fig = go.Figure(data=[go.Bar(x=top_counts.index, y=top_counts.values)])
    fig.update_layout(xaxis_title=column_name, yaxis_title='Count')
    top_counts_color = top_counts.index.map(color_mapping)
    fig = px.bar(top_counts, x=top_counts.index, y=top_counts.values)
    fig.update_traces(marker=dict(color=top_counts_color))
    return fig


fig1 = create_bar_plot_data(highest_rated_movies, 'director')
fig2 = create_bar_plot_data(movies_with_highest_budget, 'director')
fig3 = create_bar_plot_data(movies_with_highest_votes, 'director')
fig4 = create_bar_plot_data(highest_profit_generating_movies, 'director')


fig = make_subplots(rows=4, cols=1, subplot_titles=["Highest Scored Films", "Highest Budgeted Films", "Highest Voted Films", "Highest Profit Films"])
fig.add_trace(fig1.data[0], row=1, col=1)
fig.add_trace(fig2.data[0], row=2, col=1)
fig.add_trace(fig3.data[0], row=3, col=1)
fig.add_trace(fig4.data[0], row=4, col=1)


fig.update_layout(width=1000,
                height=1200,
                title="Top Directors over the Years",
                showlegend=False)


fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="LightSteelBlue")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Obeservation: There are some interesting facts that can be observed when analyzing the performance of the directors of the years. For our analysis we focused on the peak performance only, i.e how many times they have come out at top.
#
# Christopher Nolan: Nolan takes the first position with the Highest Scored Films subseta and the Highest Voted Films subset. His films were had the highest rating for five times and highest voted for six times. Budget wise he came fifth with two instances. Although his films were economically successful but they didn't break any records.
#
# James Cameron: James Cameron is a director who always prefers high budet films. Budget wise he came at the top with four instances. Both in terms of profit and voting, he came third with 3 appearences.
#
# Steven Spielberg: In our analysis the most interesting fact that came to surface is that Steven Spielberg himself is a strong candidate as the Director. In terms of profitability he came out at top with five instance. In terms of voting he came second as well as scoring. Both were 4 instances

# %% [markdown]
# iii. Top Writers Over the Years:

# %%
fig1 = create_bar_plot_data(highest_rated_movies, 'writer')
fig2 = create_bar_plot_data(movies_with_highest_budget, 'writer')
fig3 = create_bar_plot_data(movies_with_highest_votes, 'writer')
fig4 = create_bar_plot_data(highest_profit_generating_movies, 'writer')

# Create subplots with four small bar plots
fig = make_subplots(rows=4, cols=1, subplot_titles=["Highest Scored Films", "Highest Budgeted Films", "Highest Voted Films", "Highest Profit Films"])
fig.add_trace(fig1.data[0], row=1, col=1)
fig.add_trace(fig2.data[0], row=2, col=1)
fig.add_trace(fig3.data[0], row=3, col=1)
fig.add_trace(fig4.data[0], row=4, col=1)

# Set the main plot width and height to 800x600
fig.update_layout(width=1000, height=1200, title="Top writers Across Subsets", showlegend=False)
fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="LightSteelBlue")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Obeservation: James Cameron came out as the undisputed choice as the writer.
#
# 3 times in Budget, Votes and Profit. A perfect combination.

# %% [markdown]
# iv. Highest Film Budgets over the Years:

# %%
fig = px.line(movies_with_highest_budget, x='year', y='budget', title='Highest Film Budgets over the Years')
fig.update_layout(width=1000, height=800,xaxis_title='Year', yaxis_title='Budget')
fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="LightSteelBlue")
fig.update_traces(mode='lines+markers', marker_line_width=2, marker_size=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Obeservation: The budget flow for movies have changed drastically after 1990.
#
# Before 1990 the range was from 54-70m USD
# After 1990 it rose 175m which reached its peak at 2019 with 356m USD

# %% [markdown]
# v. Profit Generatinon over the Years:

# %%
fig = px.line(movies_with_highest_budget, x='year', y='profit', title='Highest Profit over the Years')
fig.update_layout(width=1000, height=800,xaxis_title='Year', yaxis_title='Profit Generatinon over the Years')
fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="LightSteelBlue")
fig.update_traces(mode='lines+markers', marker_line_width=2, marker_size=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Obeservation:
#
# Two huge spikes of 2B USD and 2.44B USD is
# observed in the year 1997 and 2019.
#
# The overall profit margin has increased over the years from 54m to 1.5B USD
#
# Covid had affected the movie industry thus having a low profit of 158m in 2020.

# %% [markdown]
# vi. Run Time Breakdown For Profit Generating Genres:

# %%
fig = px.scatter(highest_profit_generating_movies, x="profit", y="runtime", color="genre", symbol="genre",
                 size='votes', hover_data=['runtime'], title="Run Time Breakdown For Profit Generating Genres")
fig.update_layout(width=1000, height=800,xaxis_title='Profit($/USD)', yaxis_title='Run Time (minutes)')
fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="LightSteelBlue")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Obeservation: Run time varies a lot for profit generating movies of different genres.
#
# Animation movies have a range 80-103 minutes
#
# Family movies have a range of 115-129
#
# Drama movies have a range 119-133. But an exception is also observed with a runtime of 194 minutes
#
# Adventure movies have a range of 115-152 minutes
#
# Action movies have the most largest range and variation. Starting from 110 to 201 minutes.

# %% [markdown]
# Key Insights:
# Action movies dominate the genre space in all fields: Highest Budget, Highest Vote, Highest Score, Highest Profit
#
# Nolan, Cameron and Spielberg himself, are the directors to look out for.
#
# Cameron in terms of film writing, is one the of the undisputed guy in the field.
#
# Lack of Female personalities in cases of Direction/Writing was observed.
#
# Fluctuation of budget is observed after 1990.
#
# Two massive spikes in the figures of 2 and 2.44 Billion USD is observed in 1997 and 2019.
#
# Covid had affected the movie industry thus having a low profit of 158m in 2020.
